# %% [markdown]
# <a href="https://colab.research.google.com/github/WittmannF/br-data-science/blob/master/python/challenges/Desafio_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desafio 5
# Você trabalha em uma loja de sapatos e deve contatar uma lista de clientes dada pela seguinte lista de números de telefones:

# %%
numeros_telefone = [
'(765) 368-1506',
'(285) 608-2448',
'(255) 826-9050',
'(554) 994-1517',
'(285) 608-2448',
'(596) 336-5508',
'(511) 821-7870',
'(410) 665-4447',
'(821) 642-8987',
'(285) 608-2448',
'(311) 799-3883',
'(935) 875-2054',
'(464) 788-2397',
'(765) 368-1506',
'(650) 684-1437',
'(812) 816-0881',
'(285) 608-2448',
'(885) 407-1719',
'(943) 769-1061',
'(596) 336-5508',
'(765) 368-1506',
'(255) 826-9050',
]

# %% [markdown]
# No entanto, alguns destes números estão duplicados. Você seria capaz de remover estes duplicados para evitar que clientes sejam contatado mais de uma vez?

# %%
for telefone in set(numeros_telefone):
  print(f'Ligando para o cliente {telefone}')
# Out:
# Ligando para o cliente (464) 788-2397
# Ligando para o cliente (812) 816-0881
# Ligando para o cliente (410) 665-4447
# Ligando para o cliente (650) 684-1437
# Ligando para o cliente (935) 875-2054
# Ligando para o cliente (885) 407-1719
# Ligando para o cliente (554) 994-1517
# Ligando para o cliente (596) 336-5508
# Ligando para o cliente (511) 821-7870
# Ligando para o cliente (285) 608-2448
# Ligando para o cliente (311) 799-3883
# Ligando para o cliente (821) 642-8987
# Ligando para o cliente (943) 769-1061
# Ligando para o cliente (255) 826-9050
# Ligando para o cliente (765) 368-1506
